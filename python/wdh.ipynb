# %%
# Class Object/Intance Attribute Method

# def farbe(user_input="black"):
#     print(user_input)

# print("Sie wünschen die Farbe")
# farbe("blau")

# Klasse
class Auto:
    def __init__(self, farbe= "black"):
        # Hier listen wir die Attribute
        self.farbe = input("Welche Frabe wünschen sie?")
        self.ps = 200
        self.wheels = 4

    # Methoden
    def color_check(self):
        return f"Meine Farbe ist {self.farbe}"

# Objekt

auto_1 = Auto()
auto_2 = Auto()

print(f"Das erste Auto hat die Farbe: {auto_1.farbe}")
print(f"Das zweite Auto hat die Farbe: {auto_2.farbe}")

print(auto_1.color_check())
# Out:
# Das erste Auto hat die Farbe: weiß
# Das zweite Auto hat die Farbe: blau
# Meine Farbe ist weiß
